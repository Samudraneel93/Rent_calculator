# %% [markdown]
# ##Inputs We Need From The User
# #Total Rent
# #Total Food
# #Total Electricity Consumption
# #Charge per unit of electricity consumed
# #Persons living in the room/flat

# %%
rent=int(input("Enter your hostel/flat rent: "))
food=int(input("enter the amount of food ordered: "))
electricity_consumption=int(input("Enter the total amount of electricity consumed: "))
charge_per_unit=int(input("Enter the charge per unit: "))
persons=int(input("Enter the number of persons living in the flat: "))
total_bill= electricity_consumption * charge_per_unit
output=(rent + food + total_bill)//persons
print("Each person's Share :",output)
# Out:
# Enter your hostel/flat rent:  6000
# enter the amount of food ordered:  4000
# Enter the total amount of electricity consumed:  500
# Enter the charge per unit:  15
# Enter the number of persons living in the flat:  4
# Each person's Share : 4375
